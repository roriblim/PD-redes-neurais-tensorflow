# %%
import pandas as pd
df_r1 = pd.read_csv("1-resultados_testes_funcoes_de_ativacao.csv")

# primeiro ajuste no modelo em relacao ao da materia passada: tanh na camada intermediária

df_r1
# Out:
#    hidden_layers  dropout optimizer output_activation intermediate_activation  \
# 0       [32, 16]      0.1      adam           sigmoid                    relu
# 1    [32, 16, 8]      0.1      adam           sigmoid                    relu
# 2    [32, 16, 4]      0.1      adam           sigmoid                    relu
# 3       [32, 16]      0.1      adam              tanh                    relu
# 4    [32, 16, 8]      0.1      adam              tanh                    relu
# 5    [32, 16, 4]      0.1      adam              tanh                    relu
# 6       [32, 16]      0.1      adam           sigmoid                    tanh
# 7    [32, 16, 8]      0.1      adam           sigmoid                    tanh
# 8    [32, 16, 4]      0.1      adam           sigmoid                    tanh
# 9       [32, 16]      0.1      adam              tanh                    tanh
# 10   [32, 16, 8]      0.1      adam              tanh                    tanh
# ...

# %%
import pandas as pd
df_r2 = pd.read_csv("2-resultados_testes_loss_type.csv")

# primeiro ajuste no modelo em relacao ao da materia passada: tanh na camada intermediária

df_r2
# Out:
#   hidden_layers  dropout optimizer output_activation intermediate_activation  \
# 0      [32, 16]      0.1      adam           sigmoid                    tanh
# 1   [32, 16, 8]      0.1      adam           sigmoid                    tanh
# 2   [32, 16, 4]      0.1      adam           sigmoid                    tanh
# 3      [32, 16]      0.1      adam           sigmoid                    tanh
# 4   [32, 16, 8]      0.1      adam           sigmoid                    tanh
# 5   [32, 16, 4]      0.1      adam           sigmoid                    tanh
#
#              loss_type      loss  accuracy    recall  precision  f1_score
# 0                  mse  0.061804  0.923133  0.850562   0.734239  0.788131
# 1                  mse  0.064904  0.922761  0.855235   0.731476  0.788529
# 2                  mse  0.074878  0.907994  0.796476   0.702112  0.746323
# 3  binary_crossentropy  0.235112  0.924270  0.850741   0.739315  0.791124
# ...

# %%
import pandas as pd
df_r3 = pd.read_csv("3-resultados_testes_dropout.csv")

# primeiro ajuste no modelo em relacao ao da materia passada: tanh na camada intermediária

df_r3
# Out:
#    hidden_layers  dropout optimizer output_activation intermediate_activation  \
# 0       [32, 16]     0.00      adam           sigmoid                    tanh
# 1    [32, 16, 8]     0.00      adam           sigmoid                    tanh
# 2    [32, 16, 4]     0.00      adam           sigmoid                    tanh
# 3       [32, 16]     0.05      adam           sigmoid                    tanh
# 4    [32, 16, 8]     0.05      adam           sigmoid                    tanh
# 5    [32, 16, 4]     0.05      adam           sigmoid                    tanh
# 6       [32, 16]     0.10      adam           sigmoid                    tanh
# 7    [32, 16, 8]     0.10      adam           sigmoid                    tanh
# 8    [32, 16, 4]     0.10      adam           sigmoid                    tanh
# 9       [32, 16]     0.15      adam           sigmoid                    tanh
# 10   [32, 16, 8]     0.15      adam           sigmoid                    tanh
# ...

# %%
import pandas as pd
df_r4 = pd.read_csv("4-resultados_testes_camadas_intermediarias.csv")

# primeiro ajuste no modelo em relacao ao da materia passada: tanh na camada intermediária

df_r4
# Out:
#         hidden_layers  dropout optimizer output_activation  \
# 0    [32, 8, 8, 4, 2]     0.05      adam           sigmoid
# 1      [32, 16, 8, 4]     0.05      adam           sigmoid
# 2      [32, 16, 4, 2]     0.05      adam           sigmoid
# 3   [16, 16, 4, 4, 2]     0.05      adam           sigmoid
# 4      [16, 16, 8, 4]     0.05      adam           sigmoid
# 5   [32, 16, 8, 4, 2]     0.05      adam           sigmoid
# 6   [64, 16, 8, 4, 2]     0.05      adam           sigmoid
# 7       [16, 8, 4, 2]     0.05      adam           sigmoid
# 8          [16, 8, 4]     0.05      adam           sigmoid
# 9      [64, 32, 8, 4]     0.05      adam           sigmoid
# 10   [32, 8, 8, 4, 2]     0.10      adam           sigmoid
# 11     [32, 16, 8, 4]     0.10      adam           sigmoid
# 12     [32, 16, 4, 2]     0.10      adam           sigmoid
# 13  [16, 16, 4, 4, 2]     0.10      adam           sigmoid
# 14     [16, 16, 8, 4]     0.10      adam           sigmoid
# ...

# %%
import pandas as pd
df_r5 = pd.read_csv("5-resultados_testes_camadas_intermediarias-64.csv")

# primeiro ajuste no modelo em relacao ao da materia passada: tanh na camada intermediária

df_r5
# Out:
#           hidden_layers  dropout optimizer output_activation  \
# 0    [64, 16, 16, 8, 4]     0.05      adam           sigmoid
# 1     [64, 32, 8, 4, 2]     0.05      adam           sigmoid
# 2        [64, 16, 4, 2]     0.05      adam           sigmoid
# 3   [64, 40, 32, 16, 4]     0.05      adam           sigmoid
# 4   [64, 32, 32, 16, 4]     0.05      adam           sigmoid
# 5    [64, 32, 32, 8, 4]     0.05      adam           sigmoid
# 6        [64, 32, 8, 2]     0.05      adam           sigmoid
# 7   [64, 40, 32, 16, 4]     0.05      adam           sigmoid
# 8        [64, 32, 8, 4]     0.05      adam           sigmoid
# 9    [64, 16, 16, 8, 4]     0.10      adam           sigmoid
# 10    [64, 32, 8, 4, 2]     0.10      adam           sigmoid
# 11       [64, 16, 4, 2]     0.10      adam           sigmoid
# 12  [64, 40, 32, 16, 4]     0.10      adam           sigmoid
# 13  [64, 32, 32, 16, 4]     0.10      adam           sigmoid
# ...

# %%
import pandas as pd
df_r6 = pd.read_csv("6-resultados_testes_camadas_intermediarias-64-pt2.csv")

# primeiro ajuste no modelo em relacao ao da materia passada: tanh na camada intermediária

df_r6
# Out:
#                  hidden_layers  dropout optimizer output_activation  \
# 0          [64, 40, 32, 16, 4]     0.05      adam           sigmoid
# 1      [64, 40, 32, 20, 16, 4]     0.05      adam           sigmoid
# 2          [64, 64, 32, 16, 4]     0.05      adam           sigmoid
# 3        [64, 32, 16, 8, 4, 2]     0.05      adam           sigmoid
# 4               [64, 32, 8, 4]     0.05      adam           sigmoid
# 5   [64, 40, 32, 20, 16, 8, 4]     0.05      adam           sigmoid
# 6   [64, 64, 32, 32, 16, 8, 4]     0.05      adam           sigmoid
# 7       [64, 64, 32, 16, 8, 4]     0.05      adam           sigmoid
# 8   [64, 64, 40, 32, 16, 8, 4]     0.05      adam           sigmoid
# 9               [64, 32, 8, 2]     0.05      adam           sigmoid
# 10              [64, 64, 8, 2]     0.05      adam           sigmoid
# 11              [64, 64, 8, 4]     0.05      adam           sigmoid
# 12          [64, 64, 40, 8, 4]     0.05      adam           sigmoid
# ...

# %%
import pandas as pd
df_r7 = pd.read_csv("7-resultados_testes_camadas_intermediarias-128.csv")

# primeiro ajuste no modelo em relacao ao da materia passada: tanh na camada intermediária

df_r7
# Out:
#                  hidden_layers  dropout optimizer output_activation  \
# 0  [128, 80, 64, 32, 16, 8, 4]     0.05      adam           sigmoid
# 1      [128, 80, 64, 32, 8, 4]     0.05      adam           sigmoid
# 2               [80, 32, 8, 4]     0.05      adam           sigmoid
# 3           [80, 64, 32, 8, 4]     0.05      adam           sigmoid
# 4              [100, 32, 8, 4]     0.05      adam           sigmoid
# 5          [100, 64, 32, 8, 4]     0.05      adam           sigmoid
# 6              [128, 32, 8, 4]     0.05      adam           sigmoid
# 7          [128, 64, 32, 8, 4]     0.05      adam           sigmoid
# 8               [64, 32, 8, 4]     0.05      adam           sigmoid
#
#   intermediate_activation            loss_type      loss  accuracy    recall  \
# 0                    tanh  binary_crossentropy  0.227100  0.932981  0.810112
# 1                    tanh  binary_crossentropy  0.198335  0.945093  0.848417
# ...

# %%
import pandas as pd
df_r8 = pd.read_csv("8-resultados_testes_optimizadores.csv")

# primeiro ajuste no modelo em relacao ao da materia passada: tanh na camada intermediária

df_r8
# Out:
#     hidden_layers  dropout optimizer output_activation  \
# 0  [64, 32, 8, 4]     0.05      adam           sigmoid
# 1  [64, 32, 8, 4]     0.05   rmsprop           sigmoid
# 2  [64, 32, 8, 4]     0.05       sgd           sigmoid
# 3  [64, 32, 8, 4]     0.05   adagrad           sigmoid
# 4  [64, 32, 8, 4]     0.05  adadelta           sigmoid
# 5  [64, 32, 8, 4]     0.05     nadam           sigmoid
#
#   intermediate_activation            loss_type      loss  accuracy    recall  \
# 0                    tanh  binary_crossentropy  0.213381  0.940178  0.846195
# 1                    tanh  binary_crossentropy  0.206446  0.930332  0.803192
# 2                    tanh  binary_crossentropy  0.523248  0.727346  0.601966
# 3                    tanh  binary_crossentropy  0.448457  0.786049  0.674974
# 4                    tanh  binary_crossentropy  0.533160  0.744414  0.787155
# 5                    tanh  binary_crossentropy  0.212613  0.944717  0.859806
#
#    precision  f1_score
# ...
